# %%
import matplotlib.pyplot as plt
import random

# %%
# 绘图
# 1.fig
plt.figure(figsize=(20, 10), dpi=200)
plt.subplot(1,2,1)
# 2.写入数据
plt.plot([1,2,3], [4,5,6])
plt.subplot(1,2,2)
# 2.写入数据
plt.plot([1,2,3], [4,5,6])
# 3.show()
plt.show()
